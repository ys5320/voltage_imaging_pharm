# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
wm_all = pd.read_csv(r'R:\home\firefly_link\cancer\analysis\full\tc\wm_none_active_tcs_filt.csv')
from pathlib import Path
save_dir = Path(r'C:\Users\Firefly\Desktop\wm_all')
wm_all
# Out:
#      Unnamed: 0 exp_stage                                              trial  \
# 0             0   wm_none  cancer_20220728_slip1_area1_long_acq_cancer202...
# 1             1   wm_none  cancer_20220728_slip1_area1_long_acq_cancer202...
# 2             2   wm_none  cancer_20220728_slip1_area1_long_acq_cancer202...
# 3             3   wm_none  cancer_20220728_slip1_area1_long_acq_cancer202...
# 4             4   wm_none  cancer_20220728_slip1_area1_long_acq_cancer202...
# ..          ...       ...                                                ...
# 324         324   wm_none  cancer_20220729_slip2_area4_long_acq_cancer202...
# 325         325   wm_none  cancer_20220729_slip2_area4_long_acq_cancer202...
# 326         326   wm_none  cancer_20220729_slip2_area5_long_acq_cancer202...
# 327         327   wm_none  cancer_20220729_slip2_area5_long_acq_cancer202...
# 328         328   wm_none  cancer_20220729_slip2_area5_long_acq_cancer202...
#
# ...

# %%
trials = wm_all.trial.unique()
for t in trials:
    ts = wm_all[wm_all.trial == t].iloc[:,4:]
    ts.to_csv(Path(save_dir, f'{t}.csv'))
    T=0.2


    fig,ax=plt.subplots(figsize=(20,ts.shape[0]*0.3))
    ax.plot(np.arange(ts.shape[1])*T,ts.T+ np.arange(ts.shape[0])/70)
    ax.set_title(t,fontsize=18)
    #ax.set_xlabel('Time(s)')
    #ax.set_ylabel('Fluorescence df/F')
    ax.set_xticks([])
    ax.set_yticks([])
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['bottom'].set_color('none')
    ax.axis('off')
# Out:
# C:\Users\Firefly\anaconda3\envs\cancer_tutorial\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
